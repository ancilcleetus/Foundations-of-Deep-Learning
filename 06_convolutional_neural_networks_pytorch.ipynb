# %% [markdown]
# # Convolutional Neural Networks with PyTorch

# %%
# Basic Imports
import numpy as np
import scipy.signal
import torch
import torch.nn as nn

# %% [markdown]
# ## What is Convolution ?

# %%
a = [1, 2, 3, 4]
b = [5, 6, 7, 8]
# a * b
result = np.convolve(a, b)
print(f"result = {result}")
# Out:
# result = [ 5 16 34 60 61 52 32]

# %%
arr1 = np.random.random(100000)
arr2 = np.random.random(100000)

# %%
# %%timeit
np.convolve(arr1, arr2)
# Out:
# 4.61 s ± 2.07 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
a = [1, 2, 3, 4]
b = [5, 6, 7, 8]
# a * b
result = scipy.signal.fftconvolve(a, b)
print(f"result = {result}")
# Out:
# result = [ 5. 16. 34. 60. 61. 52. 32.]

# %%
# %%timeit
scipy.signal.fftconvolve(arr1, arr2)
# Out:
# 10.5 ms ± 2.02 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Convolution Examples

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path = "/content/Emma-Stone.jpg"

# Load the image (read as BGR image)
image = cv2.imread(image_path)

# Convert image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
def visualize_images(image_rgb, output_image):
  # Create a figure with two subplots
  fig, axes = plt.subplots(1, 2, figsize=(12, 6))

  # Plot the original image on the first subplot
  axes[0].imshow(image_rgb)
  axes[0].set_title('Original Image')
  axes[0].axis('off')

  # Plot the output image on the second subplot
  axes[1].imshow(output_image, cmap='gray')  # Use 'gray' colormap for grayscale images
  axes[1].set_title('Output Image (Convolved)')
  axes[1].axis('off')

  # Show the subplots
  plt.show()

# %% [markdown]
# ### Kernel for Blur (using averaging)

# %%
kernel = np.array([
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9],
])

output_image = cv2.filter2D(image, -1, kernel)
visualize_images(image_rgb, output_image)
